# %%
from google.cloud import bigquery
import pandas

# %%
client = bigquery.Client(location="US")
print("Client creating using default project: {}".format(client.project))
# Out:
# Client creating using default project: ut-goog

# %% [markdown]
# ### Query the columns from CFPB Complaints Dataset and return results in a Pandas dataframe

# %%
query = """
    SELECT 
      complaint_id,
      consumer_complaint_narrative,
      company_public_response,
      company_name,
      tags,
      consumer_consent_provided,
      submitted_via,
      date_sent_to_company,
      company_response_to_consumer,
      timely_response,
      consumer_disputed
    FROM `bigquery-public-data.cfpb_complaints.complaint_database`
    LIMIT 10
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

complaints_df = query_job.to_dataframe()
complaints_df

# %% [markdown]
# ### Calculate the percentage of null values in each column

# %%
query = """
    SELECT
      100*(COUNT(*) - COUNT(complaint_id)) / COUNT(*) AS complaint_id,
      100*(COUNT(*) - COUNT(consumer_complaint_narrative)) / COUNT(*) AS consumer_complaint_narrative,
      100*(COUNT(*) - COUNT(company_public_response)) / COUNT(*) AS company_public_response,
      100*(COUNT(*) - COUNT(company_name)) / COUNT(*) AS company_name,
      100*(COUNT(*) - COUNT(tags)) / COUNT(*) AS tags,
      100*(COUNT(*) - COUNT(consumer_consent_provided)) / COUNT(*) AS consumer_consent_provided,
      100*(COUNT(*) - COUNT(submitted_via)) / COUNT(*) AS submitted_via,
      100*(COUNT(*) - COUNT(date_sent_to_company)) / COUNT(*) AS date_sent_to_company,
      100*(COUNT(*) - COUNT(company_response_to_consumer)) / COUNT(*) AS company_response_to_consumer,
      100*(COUNT(*) - COUNT(timely_response)) / COUNT(*) AS timely_response,
      100*(COUNT(*) - COUNT(consumer_disputed)) / COUNT(*) AS consumer_disputed
    FROM `bigquery-public-data.cfpb_complaints.complaint_database`
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

complaints_nulls = query_job.to_dataframe()
complaints_nulls
# Out:
#    complaint_id  consumer_complaint_narrative  company_public_response  \
# 0           0.0                      67.15356                62.422046
#
#    company_name       tags  consumer_consent_provided  submitted_via  \
# 0           0.0  86.398418                   1.182596            0.0
#
#    date_sent_to_company  company_response_to_consumer  timely_response  \
# 0                   0.0                      0.000067              0.0
#
#    consumer_disputed
# 0          48.874884

# %% [markdown]
# The columns - consumer_complaint_narrative, company_public_response and tags have a high percentage of NULL values.
# Let's check if the consumer_complaint_narrative has enough number of rows to work with.

# %%
query = """
    SELECT
      SUM(CASE WHEN consumer_complaint_narrative IS NOT NULL THEN 1 ELSE 0 END) consumer_complaint_narrative,
      SUM(CASE WHEN company_public_response IS NOT NULL THEN 1 ELSE 0 END) company_public_response
    FROM `bigquery-public-data.cfpb_complaints.complaint_database`      
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

complaints_non_null = query_job.to_dataframe()
complaints_non_null
# Out:
#    consumer_complaint_narrative  company_public_response
# 0                        493726                   564847

# %% [markdown]
# ### Visualize the rows where the consumer_complaint_narrative is not null

# %%
query = """
    SELECT 
      *
    FROM `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE consumer_complaint_narrative IS NOT NULL
    LIMIT 100
"""

query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

complaints_df = query_job.to_dataframe()
complaints_df
# Out:
#    date_received       product                              subproduct  issue  \
# 0     2017-04-02  Prepaid card                    General purpose card   Fees
# 1     2017-01-29  Prepaid card  Electronic Benefit Transfer / EBT card   Fees
# 2     2015-12-24  Prepaid card                    General purpose card   Fees
# 3     2015-10-13  Prepaid card         Government benefit payment card   Fees
# 4     2015-12-18  Prepaid card                           Mobile wallet   Fees
# ..           ...           ...                                     ...    ...
# 95    2016-08-15   Credit card                                    None  Other
# 96    2016-07-25   Credit card                                    None  Other
# 97    2016-10-31   Credit card                                    None  Other
# 98    2015-11-10   Credit card                                    None  Other
# 99    2015-03-20   Credit card                                    None  Other
#
#    subissue                       consumer_complaint_narrative  \
# 0      None  I bought a {$400.00} prepaid Mastercard at XXX...
# 1      None  I receive monthly stipend for being a XXXX via...
# 2      None  Without receiving any notification that my acc...
# 3      None  Rush card was under maintance Monday XXXX XXXX...
# 4      None  Paypal reported 30 day delinquency against for...
# ..      ...                                                ...
# 95     None  My credit monitoring service has flagged a har...
# 96     None  Capitol One Bank XXXX The creditor did obtain ...
# 97     None  CFPB complaint XX/XX/2016 This is request for ...
# 98     None  Robocall from " XXXX '' asking for information...
# 99     None  I used a XXXX gift card to make a purchase at ...
#
#                               company_public_response  \
# 0                                                None
# 1                                                None
# 2    Company chooses not to provide a public response
# 3                                                None
# 4   Company has responded to the consumer and the ...
# ..                                                ...
# 95  Company has responded to the consumer and the ...
# 96                                               None
# 97                                               None
# 98                                               None
# 99   Company chooses not to provide a public response
#
#                          company_name state zip_code  tags  \
# 0     Blackhawk Network Holdings Inc.    OH    450XX  None
# 1                            Comerica    NJ     None  None
# 2                        U.S. BANCORP    NC    287XX  None
# 3           Empowerment Ventures, LLC    MI    490XX  None
# 4                 SYNCHRONY FINANCIAL    PA    19134  None
# ..                                ...   ...      ...   ...
# 95                     CITIBANK, N.A.    MD     None  None
# 96  CAPITAL ONE FINANCIAL CORPORATION    CT     None  None
# 97  CAPITAL ONE FINANCIAL CORPORATION    AZ    856XX  None
# 98               JPMORGAN CHASE & CO.    NJ     None  None
# 99                       U.S. BANCORP    NY     None  None
#
#    consumer_consent_provided submitted_via date_sent_to_company  \
# 0           Consent provided           Web           2017-04-03
# 1           Consent provided           Web           2017-02-02
# 2           Consent provided           Web           2015-12-29
# 3           Consent provided           Web           2015-11-02
# 4           Consent provided           Web           2016-05-05
# ..                       ...           ...                  ...
# 95          Consent provided           Web           2016-08-15
# 96          Consent provided           Web           2016-07-25
# 97          Consent provided           Web           2016-10-31
# 98          Consent provided           Web           2015-11-10
# 99          Consent provided           Web           2015-03-31
#
#        company_response_to_consumer  timely_response  consumer_disputed  \
# 0           Closed with explanation             True              False
# 1           Closed with explanation             True              False
# 2           Closed with explanation             True              False
# 3   Closed with non-monetary relief             True              False
# 4           Closed with explanation             True              False
# ..                              ...              ...                ...
# 95  Closed with non-monetary relief             True              False
# 96          Closed with explanation             True              False
# 97          Closed with explanation             True               True
# 98          Closed with explanation             True              False
# 99      Closed with monetary relief             True              False
#
#    complaint_id
# 0       2415190
# 1       2316550
# 2       1716861
# 3       1604786
# 4       1708970
# ..          ...
# 95      2063356
# 96      2029527
# 97      2186763
# 98      1648745
# 99      1294027
#
# [100 rows x 18 columns]
